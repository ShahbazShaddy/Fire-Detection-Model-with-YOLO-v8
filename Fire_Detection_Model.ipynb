# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.9 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/drive/MyDrive/Yolo_Data/data/data.yaml epochs=15 imgsz=640
# Out:
# ...
# Ultralytics 8.3.183 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
